# %%
list_soothing = set(['진정', '자극', '트러블', '여드름', '순하다', '효과', '좁쌀', '예민', '제거', '나다', '민감',
                 '민감성', '피지', '올라오다', '어성초', '붉다', '티트리', '가라', '앉다' ])
list_moisturizing = set(['보습', '건조', '건성', '수분', '흡수', '촉촉하다', '타입', '겨울', '지성', '여름',
                     '수분감', '속건조', '복합성' '채우다' '촉촉' '수부지', ])
list_skin = set(['각질', '모공', '피부결', '크다', '부드럽다', '정돈', '화장솜', '장벽', '탄력', '보호'])


import pandas as pd
advertisement = pd.read_csv('oliveyoung_advertisement_preprocessed.csv')
advertisement_ad = advertisement.iloc[:, 4:]




for i in range(len(advertisement_ad)):
    ad = advertisement_ad.iloc[i]['ad']
    words = ad.split()
    dict = {'list_soothing': 0, 'list_moisturizing': 0, 'list_skin': 0}

    for wordlist_name, count in dict.items():

        for word in words:
            if word in eval(wordlist_name):
                dict[wordlist_name] += 1
    print(dict)
# Out:
# {'list_soothing': 20, 'list_moisturizing': 2, 'list_skin': 3}
# {'list_soothing': 28, 'list_moisturizing': 5, 'list_skin': 8}
# {'list_soothing': 12, 'list_moisturizing': 17, 'list_skin': 16}
# {'list_soothing': 63, 'list_moisturizing': 54, 'list_skin': 27}
# {'list_soothing': 14, 'list_moisturizing': 5, 'list_skin': 1}
# {'list_soothing': 1, 'list_moisturizing': 23, 'list_skin': 8}
# {'list_soothing': 16, 'list_moisturizing': 29, 'list_skin': 3}
# {'list_soothing': 17, 'list_moisturizing': 2, 'list_skin': 3}
# {'list_soothing': 45, 'list_moisturizing': 13, 'list_skin': 27}
# {'list_soothing': 12, 'list_moisturizing': 4, 'list_skin': 1}
# {'list_soothing': 9, 'list_moisturizing': 33, 'list_skin': 6}
# {'list_soothing': 11, 'list_moisturizing': 6, 'list_skin': 12}
# {'list_soothing': 2, 'list_moisturizing': 36, 'list_skin': 6}
# {'list_soothing': 10, 'list_moisturizing': 19, 'list_skin': 17}
# {'list_soothing': 9, 'list_moisturizing': 18, 'list_skin': 3}
# ...
