# %%
#test

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Colab Notebooks/commit/young

# %%
# !git config --global user.email 'ind07229@naver.com'
